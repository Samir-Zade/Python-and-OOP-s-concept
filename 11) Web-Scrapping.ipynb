# %%
#import the required libries
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "iphone12pro"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
urlclient = urlopen(flipcart_url)

# %%
urlclient

# %%
flipkart_page = urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.9e9635.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
#it's manuaally
"https://www.flipkart.com/" + "apple-iphone-11-green-64-gb/p/itm386a85013a3d1?pid=MOBFWQ6BHPMG29QM&lid=LSTMOBFWQ6BHPMG29QMKXJSSF&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&iid=3205552a-a2b5-40af-9a6f-bd47904b4d0f.MOBFWQ6BHPMG29QM.SEARCH&ssid=37c36tvyr40000001708306744086&qH=d6db477051465f9a"
# Out:
# 'https://www.flipkart.com/apple-iphone-11-green-64-gb/p/itm386a85013a3d1?pid=MOBFWQ6BHPMG29QM&lid=LSTMOBFWQ6BHPMG29QMKXJSSF&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_1&otracker=search&iid=3205552a-a2b5-40af-9a6f-bd47904b4d0f.MOBFWQ6BHPMG29QM.SEARCH&ssid=37c36tvyr40000001708306744086&qH=d6db477051465f9a'

# %%
#let's extract data by automatic way for only one link then for all
bigbox = flipkart_html.find_all("div", {"class" : "_1AtVbE col-12-12"})

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone12pro&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=
# ...

# %%
len(bigbox)
# Out:
# 29

# %%
#as bigbox contain some block of data which is of header size, so we have to remove it as it not contain actual data
del bigbox[0:3]

# %%
len(bigbox)
# Out:
# 26

# %%
bigbox[1]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWBYZVRPH2UCD" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-12-pro-pacific-blue-256-gb/p/itmea897274baa30?pid=MOBFWBYZVRPH2UCD&amp;lid=LSTMOBFWBYZVRPH2UCDKBB2PK&amp;marketplace=FLIPKART&amp;q=iphone12pro&amp;store=tyy%2F4io&amp;srno=s_1_3&amp;otracker=search&amp;fm=organic&amp;iid=33ea1bf0-60cb-4773-aa7e-ae410949fcb8.MOBFWBYZVRPH2UCD.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=b4i9utdmr40000001708309553770&amp;qH=712933e6bd68e7b9" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 12 Pro (Pacific Blue, 256 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/kg8avm80/mobile/u/c/d/apple-iphone-12-pro-dummyapplefsn-original-imafwgbrzxg3nggd.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label cla
# ...

# %%
productlink = "https://www.flipkart.com" + bigbox[3].div.div.div.a["href"]

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-pro-pacific-blue-512-gb/p/itm8a39d6779b04e?pid=MOBFWBYZTHSXKMGW&lid=LSTMOBFWBYZTHSXKMGWYPOFI5&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=33ea1bf0-60cb-4773-aa7e-ae410949fcb8.MOBFWBYZTHSXKMGW.SEARCH&ppt=None&ppn=None&ssid=b4i9utdmr40000001708309553770&qH=712933e6bd68e7b9'

# %%
#now extracting the data from above 'product link'
product_req = requests.get(productlink)

# %%
product_req.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.9e9635.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" s
# ...

# %%
#extracting single page dataset
product_html = bs(product_req.text, "html.parser")

# %%
#extracting the comments and rating box
comment_box = product_html.find_all("div", {"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[1].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Tushar Saini'

# %%
#extracting all the users_name
for i in comment_box:
    print(i.div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Rajkumar tiwari
# Tushar Saini
# Kirti Yadav
# Aasheesh Vats
# Pankaj Mahor
# Vinit Kar
# Rahul  Meena
# Salman Rahman
# Harsh Singh
# Anveer arora
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11664/2987300565.py in <module>
#       1 #extracting all the users_name
#       2 for i in comment_box:
# ----> 3     print(i.div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
#extracting ratings of all the comments
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 3
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11664/2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#extracting the comment's header
comment_box[0].div.div.p.text
# Out:
# 'Simply awesome'

# %%
for i in comment_box:
    print(i.div.div.p.text)
# Out:
# Simply awesome
# Fabulous!
# Nice
# Fabulous!
# Awesome
# Best in the market!
# Highly recommended
# Fabulous!
# Classy product
# Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11664/477538510.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#extracting the actual comments of users
comment_box[0].div.div.find_all("div", {"class" : ""})[0].div.text
# Out:
# 'indeed a great phone feels premium in hand but battery life is low'

# %%
for i in comment_box:
    print(i.div.div.find_all("div", {"class" : ""})[0].text)
# Out:
# indeed a great phone feels premium in hand but battery life is lowREAD MORE
# The camera is mind-blowing I love it 😘READ MORE
# Its just Perfect . Prices are a bit high .READ MORE
# A masterpiece to cherish.READ MORE
# Best designed iPhoneREAD MORE
# I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!READ MORE
# I like the most in this phone:-1. I like the size of this phone because it is easy to hold.2. The camera quality of this phone is admirable. 3. Battery backup is good.4. The new design and colour  of this phone also a plus point of its beauty.5. These  points are my personal which i like most in this phone.READ MORE
# This one of the best iPhone ever built, though battery backup isn’t good. But the user experience is brilliant.Upgraded from 11 Pro.READ MORE
# ...
